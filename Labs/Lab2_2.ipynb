# %% [markdown]
# This Notebook showcases some data analysis done on a text file downloaded from the Web.

# %%
#Import all required packages
import requests

#Force utf8 as the character encoding
import codecs 
#numpy is a package for numeric computing
import numpy as np

#nltk is a package for working with text
#pip install nltk
#Also see: http://www.nltk.org/book/
#To download ready-to-use nltk datasets run in your shell: python -m nltk.downloader popular
#You need the nltk.corpus.stopwords.words('english') for this code to run
import nltk

#matplotlib is for plotting and nice visualisations
import matplotlib
# %matplotlib inline

import pandas as pd
pd.set_option('display.max_columns', 10)  # or None
pd.set_option('display.max_rows', 100)  # or 1000
#pd.set_option('display.max_colwidth', None)  # or 199

#Package re is for regular expressions
import re 
# %config IPCompleter.greedy=True

import os
#pip install newspaper3k
from newspaper import Article

# %%
#Get a text file.
#Get book "Alice's Adventures in Wonderland" from Project Gutenberg, in text format
#Store text content to a file named alice.txt

url='http://www.gutenberg.org/cache/epub/11/pg11.txt'
text_page = requests.get(url).text
with codecs.open("alice.txt", "w", "utf8") as file:
    file.write(text_page)
#Look at the text_page object
#?text_page

#Look at the first 5000 characters of the book
print(text_page[:5000])
# Out:
# ﻿The Project Gutenberg eBook of Alice's Adventures in Wonderland
#
# This ebook is for the use of anyone anywhere in the United States and
# most other parts of the world at no cost and with almost no restrictions
# whatsoever. You may copy it, give it away or re-use it under the terms
# of the Project Gutenberg License included with this ebook or online
# at www.gutenberg.org. If you are not located in the United States,
# you will have to check the laws of the country where you are located
# before using this eBook.
#
# Title: Alice's Adventures in Wonderland
#
#
# Author: Lewis Carroll
#
# Release date: June 27, 2008 [eBook #11]
#                 Most recently updated: March 30, 2021
#
# Language: English
#
# Credits: Arthur DiBianca and David Widger
#
#
# *** START OF THE PROJECT GUTENBERG EBOOK ALICE'S ADVENTURES IN WONDERLAND ***
# [Illustration]
#
#
#
#
# Alice’s Adventures in Wonderland
#
# by Lewis Carroll
#
# THE MILLENNIUM FULCRUM EDITION 3.0
#
# Contents
#
#  CHAPTER I.     Down the Rabbit-Hole
#  CHAPTER II.    The Pool of Tears
#  CHAPTER III.   A Caucus-Race and a Long Tale
#  CHAPTER IV.    The Rabbit Sends in a Little Bill
#  CHAPTER V.     Advice from a Caterpillar
#  CHAPTER VI.    Pig and Pepper
#  CHAPTER VII.   A Mad Tea-Party
#  CHAPTER VIII.  The Queen’s Croquet-Ground
#  CHAPTER IX.    The Mock Turtle’s Story
#  CHAPTER X.     The Lobster Quadrille
#  CHAPTER XI.    Who Stole the Tarts?
#  CHAPTER XII.   Alice’s Evidence
#
#
#
#
# CHAPTER I.
# Down the Rabbit-Hole
#
#
# Alice was beginning to get very tired of sitting by her sister on the
# bank, and of having nothing to do: once or twice she had peeped into
# the book her sister was reading, but it had no pictures or
# conversations in it, “and what is the use of a book,” thought Alice
# “without pictures or conversations?”
#
# So she was considering in her own mind (as well as she could, for the
# hot day made her feel very sleepy and stupid), whether the pleasure of
# making a daisy-chain would be worth the trouble of getting up and
# picking the daisies, when suddenly a White Rabbit with pink eyes ran
# close by her.
#
# There was nothing so _very_ remarkable in that; nor did Alice think it
# so _very_ much out of the way to hear the Rabbit say to itself, “Oh
# dear! Oh dear! I shall be late!” (when she thought it over afterwards,
# it occurred to her that she ought to have wondered at this, but at the
# time it all seemed quite natural); but when the Rabbit actually _took a
# watch out of its waistcoat-pocket_, and looked at it, and then hurried
# on, Alice started to her feet, for it flashed across her mind that she
# had never before seen a rabbit with either a waistcoat-pocket, or a
# watch to take out of it, and burning with curiosity, she ran across the
# field after it, and fortunately was just in time to see it pop down a
# large rabbit-hole under the hedge.
#
# In another moment down went Alice after it, never once considering how
# in the world she was to get out again.
#
# The rabbit-hole went straight on like a tunnel for some way, and then
# dipped suddenly down, so suddenly that Alice had not a moment to think
# about stopping herself before she found herself falling down a very
# deep well.
#
# Either the well was very deep, or she fell very slowly, for she had
# plenty of time as she went down to look about her and to wonder what
# was going to happen next. First, she tried to look down and make out
# what she was coming to, but it was too dark to see anything; then she
# looked at the sides of the well, and noticed that they were filled with
# cupboards and book-shelves; here and there she saw maps and pictures
# hung upon pegs. She took down a jar from one of the shelves as she
# passed; it was labelled “ORANGE MARMALADE”, but to her great
# disappointment it was empty: she did not like to drop the jar for fear
# of killing somebody underneath, so managed to put it into one of the
# cupboards as she fell past it.
#
# “Well!” thought Alice to herself, “after such a fall as this, I shall
# think nothing of tumbling down stairs! How brave they’ll all think me
# at home! Why, I wouldn’t say anything about it, even if I fell off the
# top of the house!” (Which was very likely true.)
#
# Down, down, down. Would the fall _never_ come to an end? “I wonder how
# many miles I’ve fallen by this time?” she said aloud. “I must be
# getting somewhere near the centre of the earth. Let me see: that would
# be four thousand miles down, I think—” (for, you see, Alice had learnt
# several things of this sort in her lessons in the schoolroom, and
# though this was not a _very_ good opportunity for showing off her
# knowledge, as there was no one to listen to her, still it was good
# practice to say it over) “—yes, that’s about the right distance—but
# then I wonder what Latitude or Longitude I’ve got to?” (Alice had no
# idea what Latitude was, or Longitude either, but thought they were nice
# grand words to say.)
#
# Presently she began again. “I wonder if I shall fall right _through_
# the earth! How funny it’l

# %% [markdown]
# # Example of Descriptive Analysis

# %%
#Open the file where we stored the book "Alice's Adventures in Wonderland"
#Load data into object text
with open('alice.txt', 'r') as file:
    text = file.read()

#Example of Descriptive Analysis
#How many chapters does the book have?
#Ignore the first element at index 0 which is the pre-face, 
#not a chapter. See book structure.
chapters = text.split("CHAPTER")[1:]
chapter_lengths = [len(ch) for ch in chapters]

min_chapter_length = len(min(chapters, key=len))
max_chapter_length = len(max(chapters, key=len))

avg_chapter_length = sum(chapter_lengths)/len(chapters)
#Can use numpy for numeric computations such as mean, standard deviation
numpy_avg_chapter_length = np.mean(chapter_lengths)
stdev_chapter_length = np.std(chapter_lengths)

#?nchapters
print("Number of chapters: ", len(chapters))
print("Chapter lengths: ", chapter_lengths)
print("Min chapter length: ", min_chapter_length)
print("Max chapter length: ", max_chapter_length)
print("Avg chapter length: ", avg_chapter_length)
print("Numpy Avg chapter length: ", numpy_avg_chapter_length)
print("Deviation from avg chapter length: ", stdev_chapter_length)


data = []
data.append([len(chapters), min_chapter_length, max_chapter_length, avg_chapter_length, stdev_chapter_length])

#create a new data frame which collects features about this book
df_book_features = pd.DataFrame(data, columns=['number_chapters', 'min_chapter_length', 'max_chapter_length', 'avg_chapter_length', 'stdev_chapter_length'])

print("\ndata frame for book")
print("data frame rows and columns:", df_book_features.shape, "\n")

df_book_features.to_csv("project_gutenberg_books.csv")
df_book_features
# Out:
# Number of chapters:  24
# Chapter lengths:  [30, 27, 39, 43, 35, 24, 25, 36, 33, 31, 30, 29, 11549, 10951, 9259, 13882, 12009, 13842, 12702, 13668, 12629, 11409, 10385, 30182]
# Min chapter length:  24
# Max chapter length:  30182
# Avg chapter length:  6785.375
# Numpy Avg chapter length:  6785.375
# Deviation from avg chapter length:  7689.804206504546
#
# data frame for book
# data frame rows and columns: (1, 5)
#    number_chapters  min_chapter_length  max_chapter_length  \
# 0               24                  24               30182
#
#    avg_chapter_length  stdev_chapter_length
# 0            6785.375           7689.804207

# %% [markdown]
# # Example of Exploratory Analysis

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/georgianaifrim/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/georgianaifrim/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
#Open the file where we stored the book "Alice's Adventures in Wonderland"
#Load data into object text
with open('alice.txt', 'r') as file:
    text = file.read()

#Example of Exploratory Analysis
#Where in the text do given words occur? (visualisation)
#What are the top-20 most frequent words in this book? (summarization)
sentences = nltk.sent_tokenize(text)
words = nltk.word_tokenize(text)
#print(words[:10])
print("Number of sentences: ", len(sentences))
print("Number of words: ", len(words))

#Turn the text into an nltk object Text
alice = nltk.Text(words)
#?alice
#Where in the text do given words occur? (visualisation)
alice.dispersion_plot(["Alice", "Rabbit", "Duchess"])

# Remove all punctuation from word lists - note the use of regular expressions!
#\W Matches any non-alphanumeric character; this is equivalent to the class [^a-zA-Z0-9_].
#For more details: https://docs.python.org/3/howto/regex.html
alice = [w for w in alice if not (re.match(r'^\W+$', w) != None)]

# Convert all words to lower case
alice = [w.lower() for w in alice]

# Remove all stop words from word lists
alice = [w for w in alice if not w in nltk.corpus.stopwords.words('english')]
#print(alice[:10])

word_frequency = nltk.FreqDist(alice)
# #?word_frequency
#What are the top-10 most frequent words in this book?
print("\nMost frequent top-10 words: ", word_frequency.most_common(10))
word_frequency.plot(10)
# Out:
# Number of sentences:  1105
# Number of words:  38047
#
# Most frequent top-10 words:  [('said', 457), ('alice', 402), ('little', 127), ('one', 100), ('project', 88), ('like', 84), ('went', 83), ('would', 78), ('queen', 76), ('could', 75)]
# <Axes: title={'center': 'Lexical Dispersion Plot'}, xlabel='Samples', ylabel='Counts'>

# %%
# Crawl the website to depth 1 to download more ebooks from Project Gutenberg. 
# If this takes too long, stop downloading by interrupting the kernel from the menu above.
# !wget https://www.gutenberg.org/ebooks/ -r -l 1 --no-parent
# Out:
# --2024-01-17 16:47:22--  https://www.gutenberg.org/ebooks/
# Resolving www.gutenberg.org (www.gutenberg.org)... 152.19.134.47
# Connecting to www.gutenberg.org (www.gutenberg.org)|152.19.134.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 54134 (53K) [text/html]
# Saving to: ‘www.gutenberg.org/ebooks/index.html’
#
# www.gutenberg.org/e 100%[===================>]  52.87K  --.-KB/s    in 0.1s
#
# 2024-01-17 16:47:23 (514 KB/s) - ‘www.gutenberg.org/ebooks/index.html’ saved [54134/54134]
#
# Loading robots.txt; please ignore errors.
# --2024-01-17 16:47:23--  https://www.gutenberg.org/robots.txt
# Reusing existing connection to www.gutenberg.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 23 [text/plain]
# Saving to: ‘www.gutenberg.org/robots.txt’
#
# www.gutenberg.org/r 100%[===================>]      23  --.-KB/s    in 0s
#
# 2024-01-17 16:47:23 (4.39 MB/s) - ‘www.gutenberg.org/robots.txt’ saved [23/23]
#
# --2024-01-17 16:47:23--  https://www.gutenberg.org/ebooks/bookshelf/
# Reusing existing connection to www.gutenberg.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42477 (41K) [text/html]
# Saving to: ‘www.gutenberg.org/ebooks/bookshelf/index.html’
#
# www.gutenberg.org/e 100%[===================>]  41.48K  --.-KB/s    in 0s
#
# 2024-01-17 16:47:23 (129 MB/s) - ‘www.gutenberg.org/ebooks/bookshelf/index.html’ saved [42477/42477]
#
# --2024-01-17 16:47:23--  https://www.gutenberg.org/ebooks/offline_catalogs.html
# Reusing existing connection to www.gutenberg.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 16283 (16K) [text/html]
# Saving to: ‘www.gutenberg.org/ebooks/offline_catalogs.html’
#
# www.gutenberg.org/e 100%[===================>]  15.90K  --.-KB/s    in 0s
#
# 2024-01-17 16:47:23 (51.2 MB/s) - ‘www.gutenberg.org/ebooks/offline_catalogs.html’ saved [16283/16283]
#
# --2024-01-17 16:47:23--  https://www.gutenberg.org/ebooks/search/?sort_order=downloads
# Reusing existing connection to www.gutenberg.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 18901 (18K) [text/html]
# Saving to: ‘www.gutenberg.org/ebooks/search/index.html?sort_order=downloads’
#
# www.gutenberg.org/e 100%[===================>]  18.46K  --.-KB/s    in 0s
#
# 2024-01-17 16:47:23 (44.8 MB/s) - ‘www.gutenberg.org/ebooks/search/index.html?sort_order=downloads’ saved [18901/18901]
#
# --2024-01-17 16:47:23--  https://www.gutenberg.org/ebooks/search/?sort_order=release_date
# Reusing existing connection to www.gutenberg.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 20219 (20K) [text/html]
# Saving to: ‘www.gutenberg.org/ebooks/search/index.html?sort_order=release_date’
#
# www.gutenberg.org/e 100%[===================>]  19.75K  --.-KB/s    in 0s
#
# 2024-01-17 16:47:24 (93.6 MB/s) - ‘www.gutenberg.org/ebooks/search/index.html?sort_order=release_date’ saved [20219/20219]
#
# --2024-01-17 16:47:24--  https://www.gutenberg.org/ebooks/search/?sort_order=random
# Reusing existing connection to www.gutenberg.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 16136 (16K) [text/html]
# Saving to: ‘www.gutenberg.org/ebooks/search/index.html?sort_order=random’
#
# www.gutenberg.org/e 100%[===================>]  15.76K  --.-KB/s    in 0s
#
# 2024-01-17 16:47:24 (33.9 MB/s) - ‘www.gutenberg.org/ebooks/search/index.html?sort_order=random’ saved [16136/16136]
#
# FINISHED --2024-01-17 16:47:24--
# Total wall clock time: 1.6s
# Downloaded: 7 files, 164K in 0.1s (1.53 MB/s)
# HTTP request sent, awaiting response... 200 OK
# Length: 20110 (20K) [text/html]
# Saving to: ‘www.gutenberg.org/ebooks/bookshelf/382’
#
# www.gutenberg.org/e 100%[===================>]  19.64K  --.-KB/s    in 0.001s
#
# 2023-01-26 15:39:48 (13.4 MB/s) - ‘www.gutenberg.org/ebooks/bookshelf/382’ saved [20110/20110]
#
# --2023-01-26 15:39:48--  https://www.gutenberg.org/ebooks/bookshelf/306
# Reusing existing connection to www.gutenberg.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 11207 (11K) [text/html]
# Saving to: ‘www.gutenberg.org/ebooks/bookshelf/306’
#
# www.gutenberg.org/e 100%[===================>]  10.94K  --.-KB/s    in 0s
#
# 2023-01-26 15:39:48 (21.5 MB/s) - ‘www.gutenberg.org/ebooks/bookshelf/306’ saved [11207/11207]
#
# --2023-01-26 15:39:48--  https://www.gutenberg.org/ebooks/bookshelf/408
# Reusing existing connection to www.gutenberg.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 19780 (19K) [text/html]
# Saving to: ‘www.gutenberg.org/ebooks/bookshelf/408’
#
# www.gutenberg.org/e 100%[===================>]  19.32K  --.-KB/s    in 0.001s
#
# 2023-01-26 15:39:48 (14.7 MB/s) - ‘www.gutenberg.org/ebooks/bookshelf/408’ saved [19780/19780]
#
# --2023-01-26 15:39:48--  https://www.gutenberg.org/ebooks/bookshelf/392
# Reusing existing connection to www.gutenberg.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 19513 (19K) [text/html]
# Saving to: ‘www.gutenberg.org/ebooks/bookshelf/392’
#
# www.gutenberg.org/e 100%[===================>]  19.06K  --.-KB/s    in 0.001s
#
# 2023-01-26 15:39:48 (24.0 MB/s) - ‘www.gutenberg.org/ebooks/bookshelf/392’ saved [19513/19513]
#
# --2023-01-26 15:39:48--  https://www.gutenberg.org/ebooks/bookshelf/387
# Reusing existing connection to www.gutenberg.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 17004 (17K) [text/html]
# Saving to: ‘www.gutenberg.org/ebooks/bookshelf/387’
#
# www.gutenberg.org/e 100%[===================>]  16.61K  --.-KB/s    in 0.001s
#
# 2023-01-26 15:39:48 (11.6 MB/s) - ‘www.gutenberg.org/ebooks/bookshelf/387’ saved [17004/17004]
#
# --2023-01-26 15:39:48--  https://www.gutenberg.org/ebooks/bookshelf/380
# Reusing existing connection to www.gutenberg.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 19934 (19K) [text/html]
# Saving to: ‘www.gutenberg.org/ebooks/bookshelf/380’
#
# www.gutenberg.org/e 100%[===================>]  19.47K  --.-KB/s    in 0.001s
#
# 2023-01-26 15:39:48 (15.5 MB/s) - ‘www.gutenberg.org/ebooks/bookshelf/380’ saved [19934/19934]
#
# --2023-01-26 15:39:48--  https://www.gutenberg.org/ebooks/bookshelf/307
# Reusing existing connection to www.gutenberg.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 19720 (19K) [text/html]
# Saving to: ‘www.gutenberg.org/ebooks/bookshelf/307’
#
# www.gutenberg.org/e 100%[===================>]  19.26K  --.-KB/s    in 0.002s
#
# 2023-01-26 15:39:48 (9.92 MB/s) - ‘www.gutenberg.org/ebooks/bookshelf/307’ saved [19720/19720]
#
# --2023-01-26 15:39:48--  https://www.gutenberg.org/ebooks/bookshelf/390
# Reusing existing connection to www.gutenberg.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 20155 (20K) [text/html]
# Saving to: ‘www.gutenberg.org/ebooks/bookshelf/390’
#
# www.gutenberg.org/e 100%[===================>]  19.68K  --.-KB/s    in 0s
#
# 2023-01-26 15:39:49 (94.7 MB/s) - ‘www.gutenberg.org/ebooks/bookshelf/390’ saved [20155/20155]
#
# --2023-01-26 15:39:49--  https://www.gutenberg.org/ebooks/bookshelf/309
# Reusing existing connection to www.gutenberg.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 19699 (19K) [text/html]
# Saving to: ‘www.gutenberg.org/ebooks/bookshelf/309’
#
# www.gutenberg.org/e 100%[===================>]  19.24K  --.-KB/s    in 0.001s
#
# 2023-01-26 15:39:49 (28.0 MB/s) - ‘www.gutenberg.org/ebooks/bookshelf/309’ saved [19699/19699]
#
# --2023-01-26 15:39:49--  https://www.gutenberg.org/ebooks/bookshelf/385
# Reusing existing connection to www.gutenberg.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 19654 (19K) [text/html]
# Saving to: ‘www.gutenberg.org/ebooks/bookshelf/385’
#
# www.gutenberg.org/e 100%[===================>]  19.19K  --.-KB/s    in 0.001s
#
# 2023-01-26 15:39:49 (25.6 MB/s) - ‘www.gutenberg.org/ebooks/bookshelf/385’ saved [19654/19654]
#
# --2023-01-26 15:39:49--  https://www.gutenberg.org/ebooks/bookshelf/310
# Reusing existing connection to www.gutenberg.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 19420 (19K) [text/html]
# Saving to: ‘www.gutenberg.org/ebooks/bookshelf/310’
#
# www.gutenberg.org/e 100%[===================>]  18.96K  --.-KB/s    in 0.001s
#
# 2023-01-26 15:39:49 (16.2 MB/s) - ‘www.gutenberg.org/ebooks/bookshelf/310’ saved [19420/19420]
#
# --2023-01-26 15:39:49--  https://www.gutenberg.org/ebooks/bookshelf/311
# Reusing existing connection to www.gutenberg.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 19434 (19K) [text/html]
# Saving to: ‘www.gutenberg.org/ebooks/bookshelf/311’
#
# www.gutenberg.org/e 100%[===================>]  18.98K  --.-KB/s    in 0.001s
#
# 2023-01-26 15:39:49 (22.5 MB/s) - ‘www.gutenberg.org/ebooks/bookshelf/311’ saved [19434/19434]
#
# --2023-01-26 15:39:49--  https://www.gutenberg.org/ebooks/bookshelf/384
# Reusing existing connection to www.gutenberg.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 20015 (20K) [text/html]
# Saving to: ‘www.gutenberg.org/ebooks/bookshelf/384’
#
# www.gutenberg.org/e 100%[===================>]  19.55K  --.-KB/s    in 0.002s
#
# 2023-01-26 15:39:49 (12.6 MB/s) - ‘www.gutenberg.org/ebooks/bookshelf/384’ saved [20015/20015]
#
# --2023-01-26 15:39:49--  https://www.gutenberg.org/ebooks/bookshelf/407
# Reusing existing connection to www.gutenberg.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 16752 (16K) [text/html]
# Saving to: ‘www.gutenberg.org/ebooks/bookshelf/407’
#
# www.gutenberg.org/e 100%[===================>]  16.36K  --.-KB/s    in 0.001s
#
# 2023-01-26 15:39:50 (30.6 MB/s) - ‘www.gutenberg.org/ebooks/bookshelf/407’ saved [16752/16752]
#
# --2023-01-26 15:39:50--  https://www.gutenberg.org/ebooks/bookshelf/313
# Reusing existing connection to www.gutenberg.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 19366 (19K) [text/html]
# Saving to: ‘www.gutenberg.org/ebooks/bookshelf/313’
#
# www.gutenberg.org/e 100%[===================>]  18.91K  --.-KB/s    in 0.001s
#
# 2023-01-26 15:39:50 (35.4 MB/s) - ‘www.gutenberg.org/ebooks/bookshelf/313’ saved [19366/19366]
#
# --2023-01-26 15:39:50--  https://www.gutenberg.org/ebooks/bookshelf/337
# Reusing existing connection to www.gutenberg.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 12510 (12K) [text/html]
# Saving to: ‘www.gutenberg.org/ebooks/bookshelf/337’
#
# www.gutenberg.org/e 100%[===================>]  12.22K  --.-KB/s    in 0.001s
#
# 2023-01-26 15:39:50 (23.5 MB/s) - ‘www.gutenberg.org/ebooks/bookshelf/337’ saved [12510/12510]
#
# --2023-01-26 15:39:50--  https://www.gutenberg.org/ebooks/bookshelf/416
# Reusing existing connection to www.gutenberg.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 14242 (14K) [text/html]
# Saving to: ‘www.gutenberg.org/ebooks/bookshelf/416’
#
# www.gutenberg.org/e 100%[===================>]  13.91K  --.-KB/s    in 0s
#
# 2023-01-26 15:39:50 (28.7 MB/s) - ‘www.gutenberg.org/ebooks/bookshelf/416’ saved [14242/14242]
#
# --2023-01-26 15:39:50--  https://www.gutenberg.org/ebooks/bookshelf/315
# Reusing existing connection to www.gutenberg.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 19671 (19K) [text/html]
# Saving to: ‘www.gutenberg.org/ebooks/bookshelf/315’
#
# www.gutenberg.org/e 100%[===================>]  19.21K  --.-KB/s    in 0.001s
#
# 2023-01-26 15:39:50 (21.6 MB/s) - ‘www.gutenberg.org/ebooks/bookshelf/315’ saved [19671/19671]
#
# --2023-01-26 15:39:50--  https://www.gutenberg.org/ebooks/bookshelf/417
# Reusing existing connection to www.gutenberg.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 12024 (12K) [text/html]
# Saving to: ‘www.gutenberg.org/ebooks/bookshelf/417’
#
# www.gutenberg.org/e 100%[===================>]  11.74K  --.-KB/s    in 0s
#
# 2023-01-26 15:39:50 (33.3 MB/s) - ‘www.gutenberg.org/ebooks/bookshelf/417’ saved [12024/12024]
#
# --2023-01-26 15:39:50--  https://www.gutenberg.org/ebooks/bookshelf/395
# Reusing existing connection to www.gutenberg.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 19615 (19K) [text/html]
# Saving to: ‘www.gutenberg.org/ebooks/bookshelf/395’
#
# www.gutenberg.org/e 100%[===================>]  19.16K  --.-KB/s    in 0.001s
#
# 2023-01-26 15:39:50 (26.8 MB/s) - ‘www.gutenberg.org/ebooks/bookshelf/395’ saved [19615/19615]
#
# --2023-01-26 15:39:50--  https://www.gutenberg.org/ebooks/bookshelf/317
# Reusing existing connection to www.gutenberg.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 19495 (19K) [text/html]
# Saving to: ‘www.gutenberg.org/ebooks/bookshelf/317’
#
# www.gutenberg.org/e 100%[===================>]  19.04K  --.-KB/s    in 0.001s
#
# 2023-01-26 15:39:51 (12.7 MB/s) - ‘www.gutenberg.org/ebooks/bookshelf/317’ saved [19495/19495]
#
# --2023-01-26 15:39:51--  https://www.gutenberg.org/ebooks/bookshelf/383
# Reusing existing connection to www.gutenberg.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 13139 (13K) [text/html]
# Saving to: ‘www.gutenberg.org/ebooks/bookshelf/383’
#
# www.gutenberg.org/e 100%[===================>]  12.83K  --.-KB/s    in 0.001s
#
# 2023-01-26 15:39:51 (23.5 MB/s) - ‘www.gutenberg.org/ebooks/bookshelf/383’ saved [13139/13139]
#
# --2023-01-26 15:39:51--  https://www.gutenberg.org/ebooks/bookshelf/318
# Reusing existing connection to www.gutenberg.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 16812 (16K) [text/html]
# Saving to: ‘www.gutenberg.org/ebooks/bookshelf/318’
#
# www.gutenberg.org/e 100%[===================>]  16.42K  --.-KB/s    in 0.001s
#
# 2023-01-26 15:39:51 (20.3 MB/s) - ‘www.gutenberg.org/ebooks/bookshelf/318’ saved [16812/16812]
#
# --2023-01-26 15:39:51--  https://www.gutenberg.org/ebooks/bookshelf/386
# Reusing existing connection to www.gutenberg.org:443.
# HTTP request sent, awaiting response... 200 OK
# ^C

# %%
# This code iterates through a folder on the local computer, reads each html file and parses it
# each html file here only contains the title of the ebook and urls for different formats

rootdir = "www.gutenberg.org/ebooks"

#index = 0
for subdir, dirs, files in os.walk(rootdir):
    for file in files:
        #print os.path.join(subdir, file)
        filepath = subdir + os.sep + file
        print ("\nPath:", filepath)
        
        filename = filepath.split("/")[-1]
        print("Filename:", filename)
        
        with open(filepath, 'r') as fp:
            # using the newspaper library to read each html ebook file stored on this computer
            article = Article('', language='en')
            try:
                article.download(input_html=fp.read())
                article.parse()
    
                print("Title:", article.title)
                #print("Text:",article.text)
                #print("HTML:", article.html)
            except: print("ERROR: not an html file!")
# Out:
# Path: www.gutenberg.org/ebooks/index.html
# Filename: index.html
# Title: Project Gutenberg
#
# Path: www.gutenberg.org/ebooks/.DS_Store
# Filename: .DS_Store
# ERROR: not an html file!
#
# Path: www.gutenberg.org/ebooks/offline_catalogs.html
# Filename: offline_catalogs.html
# Title: Project Gutenberg
#
# Path: www.gutenberg.org/ebooks/bookshelf/index.html
# Filename: index.html
# Title: Project Gutenberg
#
# Path: www.gutenberg.org/ebooks/search/index.html?sort_order=release_date
# Filename: index.html?sort_order=release_date
# Title: All Books (sorted by release date)
#
# Path: www.gutenberg.org/ebooks/search/index.html?sort_order=downloads
# Filename: index.html?sort_order=downloads
# Title: All Books (sorted by popularity)
#
# Path: www.gutenberg.org/ebooks/search/index.html?sort_order=random
# Filename: index.html?sort_order=random
# Title: All Books (in random order)
